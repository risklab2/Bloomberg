# %%
import os
import pandas as pd

# Define the path to the 'Raw_data' folder and the Working_Data folder
raw_data_folder = r'C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data'  # Path to Raw_data folder
working_data_folder = os.path.join(r'C:\Users\matth\Risk-Lab-\Bloomberg', 'Working_Data')  # Path to Working_Data folder

# Check if the Raw_data folder exists
if not os.path.exists(raw_data_folder):
    print(f"The Raw_data folder does not exist: {raw_data_folder}")
else:
    print(f"Raw_data folder found: {raw_data_folder}")

    # Check if the Working_Data folder exists, create if not
    if not os.path.exists(working_data_folder):
        os.makedirs(working_data_folder)
        print(f"Created 'Working_Data' folder: {working_data_folder}")
    else:
        print(f"'Working_Data' folder already exists: {working_data_folder}")

    # Initialize a dictionary to hold DataFrames for each Excel file
    raw_dataframes = {}

    # Use os.walk to traverse the Raw_data folder and its subfolders
    for root, dirs, files in os.walk(raw_data_folder):
        print(f"Checking folder: {root}")  # Print the current folder being checked
        for file in files:
            if file.endswith('.xlsx') or file.endswith('.xls'):  # Check for Excel files
                # Construct the full file path
                excel_file_path = os.path.join(root, file)

                # Read the Excel file into a DataFrame
                df = pd.read_excel(excel_file_path)

                # Calculate the relative path from 'Raw_data' to the current folder
                relative_path = os.path.relpath(root, raw_data_folder)

                # Create the corresponding subfolder path in 'Working_Data'
                subfolder_path = os.path.join(working_data_folder, relative_path)

                # Ensure that the subfolder exists, create if necessary
                if not os.path.exists(subfolder_path):
                    os.makedirs(subfolder_path)
                    print(f"Created subfolder: {subfolder_path}")

                # Create the CSV file path within the corresponding subfolder
                csv_file_path = os.path.join(subfolder_path, os.path.splitext(file)[0] + '.csv')

                # Convert the DataFrame to CSV and save it in the correct subfolder
                df.to_csv(csv_file_path, index=False)

                # Optionally, store the DataFrame in the dictionary (if needed for further processing)
                variable_name = os.path.splitext(file)[0]  # Use the file name without extension
                raw_dataframes[variable_name] = df
                print(f"DataFrame '{variable_name}' created with shape {df.shape} and saved as CSV at {csv_file_path}.")

    # Print out the names of DataFrames created
    if raw_dataframes:
        print("DataFrames created and saved as CSVs:")
        for name in raw_dataframes:
            print(name)
    else:
        print("No Excel files found in the Raw_data folder and its subfolders.")
# Out:
# Raw_data folder found: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data
# 'Working_Data' folder already exists: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data
# DataFrame 'PX_LAST_ALL_1990' created with shape (1822, 37) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\.\PX_LAST_ALL_1990.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Communications
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Communications\GOOG
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Communications\GOOG
# DataFrame 'GOOGL_Segments_Quarter_2014' created with shape (92, 80) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Communications\GOOG\GOOGL_Segments_Quarter_2014.csv.
# DataFrame 'GOOGL_Segments_Quarter_2024' created with shape (116, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Communications\GOOG\GOOGL_Segments_Quarter_2024.csv.
# DataFrame 'GOOGL_Segments_Yearly_2023' created with shape (122, 44) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Communications\GOOG\GOOGL_Segments_Yearly_2023.csv.
# DataFrame 'GOOG_Annual' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Communications\GOOG\GOOG_Annual.csv.
# DataFrame 'GOOG_Quarter' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Communications\GOOG\GOOG_Quarter.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Communications\META
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Communications\META
# DataFrame 'META_Annual' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Communications\META\META_Annual.csv.
# DataFrame 'META_Quarter' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Communications\META\META_Quarter.csv.
# DataFrame 'META_Segments_Quarter_2014' created with shape (17, 38) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Communications\META\META_Segments_Quarter_2014.csv.
# DataFrame 'META_Segments_Quarter_2024' created with shape (46, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Communications\META\META_Segments_Quarter_2024.csv.
# DataFrame 'META_Segments_Yearly_2023' created with shape (41, 32) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Communications\META\META_Segments_Yearly_2023.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Communications\NFLX
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Communications\NFLX
# DataFrame 'NFLX_Annual' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Communications\NFLX\NFLX_Annual.csv.
# DataFrame 'NFLX_Quarter' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Communications\NFLX\NFLX_Quarter.csv.
# DataFrame 'NFLX_Segments_Quarter_2014' created with shape (112, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Communications\NFLX\NFLX_Segments_Quarter_2014.csv.
# DataFrame 'NFLX_Segments_Quarter_2024' created with shape (84, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Communications\NFLX\NFLX_Segments_Quarter_2024.csv.
# DataFrame 'NFLX_Segments_Yearly_2023' created with shape (116, 42) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Communications\NFLX\NFLX_Segments_Yearly_2023.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Consumer Discretionary
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Consumer Discretionary\BYDDY
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Discretionary\BYDDY
# DataFrame 'BYDDY_Annual' created with shape (309, 37) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Discretionary\BYDDY\BYDDY_Annual.csv.
# DataFrame 'BYDDY_Quarter' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Discretionary\BYDDY\BYDDY_Quarter.csv.
# DataFrame 'BYDDY_Segments_Annual_2003' created with shape (158, 44) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Discretionary\BYDDY\BYDDY_Segments_Annual_2003.csv.
# DataFrame 'BYDDY_Segments_Quarter_2018' created with shape (44, 54) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Discretionary\BYDDY\BYDDY_Segments_Quarter_2018.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Consumer Discretionary\TM
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Discretionary\TM
# DataFrame 'TM_Annual' created with shape (309, 60) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Discretionary\TM\TM_Annual.csv.
# DataFrame 'TM_Quarter' created with shape (169, 161) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Discretionary\TM\TM_Quarter.csv.
# DataFrame 'TM_Segments_Annual' created with shape (77, 42) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Discretionary\TM\TM_Segments_Annual.csv.
# DataFrame 'TM_Segments_Quarter_2013' created with shape (64, 42) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Discretionary\TM\TM_Segments_Quarter_2013.csv.
# DataFrame 'TM_Segments_Quarter_2018' created with shape (55, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Discretionary\TM\TM_Segments_Quarter_2018.csv.
# DataFrame 'TM_Segments_Quarter_2024' created with shape (52, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Discretionary\TM\TM_Segments_Quarter_2024.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Consumer Discretionary\TSLA
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Discretionary\TSLA
# DataFrame 'Telsa_Segments_Quarter_2024' created with shape (105, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Discretionary\TSLA\Telsa_Segments_Quarter_2024.csv.
# DataFrame 'Tesla_Segments_ Annual' created with shape (100, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Discretionary\TSLA\Tesla_Segments_ Annual.csv.
# DataFrame 'Tesla_Segments_ Quarter_2009' created with shape (47, 42) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Discretionary\TSLA\Tesla_Segments_ Quarter_2009.csv.
# DataFrame 'Tesla_Segments_Quarter_2023' created with shape (103, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Discretionary\TSLA\Tesla_Segments_Quarter_2023.csv.
# DataFrame 'TSLA_Annual' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Discretionary\TSLA\TSLA_Annual.csv.
# DataFrame 'TSLA_Quarter' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Discretionary\TSLA\TSLA_Quarter.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Consumer Staples
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Consumer Staples\COST
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\COST
# DataFrame 'Costco_Quarter_Template' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\COST\Costco_Quarter_Template.csv.
# DataFrame 'COST_Annual_Template' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\COST\COST_Annual_Template.csv.
# DataFrame 'COST_Segments_Quarter_2004' created with shape (32, 42) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\COST\COST_Segments_Quarter_2004.csv.
# DataFrame 'COST_Segments_Quarter_2014' created with shape (76, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\COST\COST_Segments_Quarter_2014.csv.
# DataFrame 'COST_Segments_Quarter_2024' created with shape (92, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\COST\COST_Segments_Quarter_2024.csv.
# DataFrame 'COST_Segments_Yearly_2024' created with shape (95, 58) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\COST\COST_Segments_Yearly_2024.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Consumer Staples\PG
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\PG
# DataFrame 'PG_Annual_Template' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\PG\PG_Annual_Template.csv.
# DataFrame 'PG_Quarter_Template' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\PG\PG_Quarter_Template.csv.
# DataFrame 'PG_Segments_Quarter_2005' created with shape (117, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\PG\PG_Segments_Quarter_2005.csv.
# DataFrame 'PG_Segments_Quarter_2015' created with shape (253, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\PG\PG_Segments_Quarter_2015.csv.
# DataFrame 'PG_Segments_Quarter_2025' created with shape (123, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\PG\PG_Segments_Quarter_2025.csv.
# DataFrame 'PG_Segments_Yearly_2024' created with shape (302, 50) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\PG\PG_Segments_Yearly_2024.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Consumer Staples\WMT
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\WMT
# DataFrame 'WMT_Annual_Template' created with shape (321, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\WMT\WMT_Annual_Template.csv.
# DataFrame 'WMT_Quarter_Template' created with shape (170, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\WMT\WMT_Quarter_Template.csv.
# DataFrame 'WMT_Segments_Quarter_2005' created with shape (69, 48) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\WMT\WMT_Segments_Quarter_2005.csv.
# DataFrame 'WMT_Segments_Quarter_2015' created with shape (210, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\WMT\WMT_Segments_Quarter_2015.csv.
# DataFrame 'WMT_Segments_Quarter_2025' created with shape (277, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\WMT\WMT_Segments_Quarter_2025.csv.
# DataFrame 'WMT_Segments_Yearly_2024' created with shape (298, 56) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Consumer Staples\WMT\WMT_Segments_Yearly_2024.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Energy
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Energy\CVX
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Energy\CVX
# DataFrame 'CVX_Annual' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Energy\CVX\CVX_Annual.csv.
# DataFrame 'CVX_Quarter' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Energy\CVX\CVX_Quarter.csv.
# DataFrame 'CVX_Segments_Annual_2000' created with shape (218, 50) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Energy\CVX\CVX_Segments_Annual_2000.csv.
# DataFrame 'CVX_Segments_Quarter_2000' created with shape (137, 32) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Energy\CVX\CVX_Segments_Quarter_2000.csv.
# DataFrame 'CVX_Segments_Quarter_2004' created with shape (145, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Energy\CVX\CVX_Segments_Quarter_2004.csv.
# DataFrame 'CVX_Segments_Quarter_2014' created with shape (146, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Energy\CVX\CVX_Segments_Quarter_2014.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Energy\PCCYF
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Energy\PCCYF
# DataFrame 'PCCYF_Annual' created with shape (309, 37) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Energy\PCCYF\PCCYF_Annual.csv.
# DataFrame 'PCCYF_Quarter' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Energy\PCCYF\PCCYF_Quarter.csv.
# DataFrame 'PCCYF_Segments_Annual_2005' created with shape (265, 40) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Energy\PCCYF\PCCYF_Segments_Annual_2005.csv.
# DataFrame 'PCCYF_Segments_Quarter_2007' created with shape (156, 56) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Energy\PCCYF\PCCYF_Segments_Quarter_2007.csv.
# DataFrame 'PCCYF_Segments_Quarter_2014' created with shape (165, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Energy\PCCYF\PCCYF_Segments_Quarter_2014.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Energy\XOM
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Energy\XOM
# DataFrame 'XOM_Annual' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Energy\XOM\XOM_Annual.csv.
# DataFrame 'XOM_Quarter' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Energy\XOM\XOM_Quarter.csv.
# DataFrame 'XOM_Segments_Annual_2000' created with shape (408, 50) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Energy\XOM\XOM_Segments_Annual_2000.csv.
# DataFrame 'XOM_Segments_Quarter_2000' created with shape (79, 38) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Energy\XOM\XOM_Segments_Quarter_2000.csv.
# DataFrame 'XOM_Segments_Quarter_2004' created with shape (79, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Energy\XOM\XOM_Segments_Quarter_2004.csv.
# DataFrame 'XOM_Segments_Quarter_2014' created with shape (269, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Energy\XOM\XOM_Segments_Quarter_2014.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Financials
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Financials\BRK-B
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\BRK-B
# DataFrame 'BRK-B_Annual' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\BRK-B\BRK-B_Annual.csv.
# DataFrame 'BRK-B_Quarter' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\BRK-B\BRK-B_Quarter.csv.
# DataFrame 'BRK-B_Segments_Annual_2000' created with shape (466, 50) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\BRK-B\BRK-B_Segments_Annual_2000.csv.
# DataFrame 'BRK-B_Segments_Quarter_2001' created with shape (161, 22) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\BRK-B\BRK-B_Segments_Quarter_2001.csv.
# DataFrame 'BRK-B_Segments_Quarter_2004' created with shape (226, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\BRK-B\BRK-B_Segments_Quarter_2004.csv.
# DataFrame 'BRK-B_Segments_Quarter_2014' created with shape (324, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\BRK-B\BRK-B_Segments_Quarter_2014.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Financials\JPM
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\JPM
# DataFrame 'JPM_Quarter_1990 - Copy-annotated-dd' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\JPM\JPM_Quarter_1990 - Copy-annotated-dd.csv.
# DataFrame 'JPM_Quarter_1990' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\JPM\JPM_Quarter_1990.csv.
# DataFrame 'JPM_Segments_Quarter_2001' created with shape (358, 32) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\JPM\JPM_Segments_Quarter_2001.csv.
# DataFrame 'JPM_Segments_Quarter_2004' created with shape (642, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\JPM\JPM_Segments_Quarter_2004.csv.
# DataFrame 'JPM_Segments_Quarter_2014' created with shape (447, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\JPM\JPM_Segments_Quarter_2014.csv.
# DataFrame 'JPM_Segments_Yearly_2001' created with shape (687, 48) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\JPM\JPM_Segments_Yearly_2001.csv.
# DataFrame 'JPM_Yearly_1990 - Copy-DD-annotated' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\JPM\JPM_Yearly_1990 - Copy-DD-annotated.csv.
# DataFrame 'JPM_Yearly_1990' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\JPM\JPM_Yearly_1990.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Financials\V
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\V
# DataFrame 'V_Quarter_1990' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\V\V_Quarter_1990.csv.
# DataFrame 'V_Segments_Quarter_2008' created with shape (113, 56) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\V\V_Segments_Quarter_2008.csv.
# DataFrame 'V_Segments_Quarter_2014' created with shape (115, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\V\V_Segments_Quarter_2014.csv.
# DataFrame 'V_Segments_Yearly_2005' created with shape (114, 40) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\V\V_Segments_Yearly_2005.csv.
# DataFrame 'V_Yearly_1990' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Financials\V\V_Yearly_1990.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Healthcare
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Healthcare\JNJ
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Healthcare\JNJ
# DataFrame 'JNJ_Quarter_1990' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Healthcare\JNJ\JNJ_Quarter_1990.csv.
# DataFrame 'JNJ_Segments_Quarterly_2001' created with shape (123, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Healthcare\JNJ\JNJ_Segments_Quarterly_2001.csv.
# DataFrame 'JNJ_Segments_Quarterly_2005' created with shape (288, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Healthcare\JNJ\JNJ_Segments_Quarterly_2005.csv.
# DataFrame 'JNJ_Segments_Quarterly_2015' created with shape (319, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Healthcare\JNJ\JNJ_Segments_Quarterly_2015.csv.
# DataFrame 'JNJ_Segments_Yearly_2001' created with shape (384, 52) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Healthcare\JNJ\JNJ_Segments_Yearly_2001.csv.
# DataFrame 'JNJ_Yearly_1990' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Healthcare\JNJ\JNJ_Yearly_1990.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Healthcare\LLY
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Healthcare\LLY
# DataFrame 'LLY_Quarter_1990' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Healthcare\LLY\LLY_Quarter_1990.csv.
# DataFrame 'LLY_Segments_Quarter_2006' created with shape (165, 74) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Healthcare\LLY\LLY_Segments_Quarter_2006.csv.
# DataFrame 'LLY_Segments_Quarter_2015' created with shape (194, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Healthcare\LLY\LLY_Segments_Quarter_2015.csv.
# DataFrame 'LLY_Segments_Yearly_2004' created with shape (223, 46) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Healthcare\LLY\LLY_Segments_Yearly_2004.csv.
# DataFrame 'LLY_Yearly_1990' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Healthcare\LLY\LLY_Yearly_1990.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Healthcare\UNH
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Healthcare\UNH
# DataFrame 'UNH_Annual_1990' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Healthcare\UNH\UNH_Annual_1990.csv.
# DataFrame 'UNH_Quarter_1990' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Healthcare\UNH\UNH_Quarter_1990.csv.
# DataFrame 'UNH_Segments_Quarter_2000' created with shape (51, 40) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Healthcare\UNH\UNH_Segments_Quarter_2000.csv.
# DataFrame 'UNH_Segments_Quarter_2004' created with shape (159, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Healthcare\UNH\UNH_Segments_Quarter_2004.csv.
# DataFrame 'UNH_Segments_Quarter_2014' created with shape (106, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Healthcare\UNH\UNH_Segments_Quarter_2014.csv.
# DataFrame 'UNH_Segments_Yearly_2000' created with shape (166, 50) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Healthcare\UNH\UNH_Segments_Yearly_2000.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Industrial
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Industrial\CAT
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Industrial\CAT
# DataFrame 'CAT_Annual_1990' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Industrial\CAT\CAT_Annual_1990.csv.
# DataFrame 'CAT_Quarter_1990' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Industrial\CAT\CAT_Quarter_1990.csv.
# DataFrame 'CAT_Segments_Quarter_2004' created with shape (58, 30) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Industrial\CAT\CAT_Segments_Quarter_2004.csv.
# DataFrame 'CAT_Segments_Quarter_2014' created with shape (421, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Industrial\CAT\CAT_Segments_Quarter_2014.csv.
# DataFrame 'CAT_Segments_Quarter_2024' created with shape (331, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Industrial\CAT\CAT_Segments_Quarter_2024.csv.
# DataFrame 'CAT_Segments_Yearly_2023' created with shape (470, 48) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Industrial\CAT\CAT_Segments_Yearly_2023.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Industrial\GE
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Industrial\GE
# DataFrame 'GE_Quarterly_1990' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Industrial\GE\GE_Quarterly_1990.csv.
# DataFrame 'GE_Segments_Quarter_2004' created with shape (337, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Industrial\GE\GE_Segments_Quarter_2004.csv.
# DataFrame 'GE_Segments_Quarter_2014' created with shape (573, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Industrial\GE\GE_Segments_Quarter_2014.csv.
# DataFrame 'GE_Segments_Yearly_2004' created with shape (640, 42) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Industrial\GE\GE_Segments_Yearly_2004.csv.
# DataFrame 'GE_Yearly_1990' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Industrial\GE\GE_Yearly_1990.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Industrial\RTX
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Industrial\RTX
# DataFrame 'RTX_Quarter_1990' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Industrial\RTX\RTX_Quarter_1990.csv.
# DataFrame 'RTX_Segments_Quarter_2004' created with shape (60, 32) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Industrial\RTX\RTX_Segments_Quarter_2004.csv.
# DataFrame 'RTX_Segments_Quarter_2014' created with shape (189, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Industrial\RTX\RTX_Segments_Quarter_2014.csv.
# DataFrame 'RTX_Segments_Quarter_2024' created with shape (305, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Industrial\RTX\RTX_Segments_Quarter_2024.csv.
# DataFrame 'RTX_Segments_Yearly_2023' created with shape (387, 48) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Industrial\RTX\RTX_Segments_Yearly_2023.csv.
# DataFrame 'RTX_Yearly_1990' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Industrial\RTX\RTX_Yearly_1990.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Materials
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Materials\DD
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Materials\DD
# DataFrame 'DD_Annual_Template' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Materials\DD\DD_Annual_Template.csv.
# DataFrame 'DD_Quarter_Template' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Materials\DD\DD_Quarter_Template.csv.
# DataFrame 'DD_Segments_Quarter_2024' created with shape (271, 70) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Materials\DD\DD_Segments_Quarter_2024.csv.
# DataFrame 'DD_Segments_Yearly_2023' created with shape (240, 18) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Materials\DD\DD_Segments_Yearly_2023.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Materials\MLM
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Materials\MLM
# DataFrame 'MLM_Annual_Template' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Materials\MLM\MLM_Annual_Template.csv.
# DataFrame 'MLM_Quarter_Template' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Materials\MLM\MLM_Quarter_Template.csv.
# DataFrame 'MLM_Segments_Quarter_2004' created with shape (31, 30) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Materials\MLM\MLM_Segments_Quarter_2004.csv.
# DataFrame 'MLM_Segments_Quarter_2014' created with shape (102, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Materials\MLM\MLM_Segments_Quarter_2014.csv.
# DataFrame 'MLM_Segments_Quarter_2024' created with shape (156, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Materials\MLM\MLM_Segments_Quarter_2024.csv.
# DataFrame 'MLM_Segments_Yearly_2023' created with shape (175, 48) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Materials\MLM\MLM_Segments_Yearly_2023.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Materials\VMC
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Materials\VMC
# DataFrame 'VMC_Annual_Template' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Materials\VMC\VMC_Annual_Template.csv.
# DataFrame 'VMC_Quarter_Template' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Materials\VMC\VMC_Quarter_Template.csv.
# DataFrame 'VMC_Segments_Quarter_2004' created with shape (27, 30) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Materials\VMC\VMC_Segments_Quarter_2004.csv.
# DataFrame 'VMC_Segments_Quarter_2014' created with shape (112, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Materials\VMC\VMC_Segments_Quarter_2014.csv.
# DataFrame 'VMC_Segments_Quarter_2024' created with shape (83, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Materials\VMC\VMC_Segments_Quarter_2024.csv.
# DataFrame 'VMC_Segments_Yearly_2023' created with shape (147, 48) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Materials\VMC\VMC_Segments_Yearly_2023.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Miscellaneous
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Miscellaneous\CSX
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\CSX
# DataFrame 'CSX_Annual' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\CSX\CSX_Annual.csv.
# DataFrame 'CSX_Quarter' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\CSX\CSX_Quarter.csv.
# DataFrame 'CSX_Segments_Annual_2003' created with shape (235, 44) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\CSX\CSX_Segments_Annual_2003.csv.
# DataFrame 'CSX_Segments_Quarter_2004' created with shape (169, 42) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\CSX\CSX_Segments_Quarter_2004.csv.
# DataFrame 'CSX_Segments_Quarter_2009' created with shape (187, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\CSX\CSX_Segments_Quarter_2009.csv.
# DataFrame 'CSX_Segments_Quarter_2014' created with shape (141, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\CSX\CSX_Segments_Quarter_2014.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Miscellaneous\NSC
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\NSC
# DataFrame 'NSC_Annual' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\NSC\NSC_Annual.csv.
# DataFrame 'NSC_Quarter' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\NSC\NSC_Quarter.csv.
# DataFrame 'NSC_Segments_Annual_2003' created with shape (171, 44) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\NSC\NSC_Segments_Annual_2003.csv.
# DataFrame 'NSC_Segments_Quarter_2003' created with shape (97, 80) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\NSC\NSC_Segments_Quarter_2003.csv.
# DataFrame 'NSC_Segments_Quarter_2013' created with shape (170, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\NSC\NSC_Segments_Quarter_2013.csv.
# DataFrame 'NSC_Segments_Quarter_2014' created with shape (170, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\NSC\NSC_Segments_Quarter_2014.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Miscellaneous\UNP
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\UNP
# DataFrame 'UNP_Annual' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\UNP\UNP_Annual.csv.
# DataFrame 'UNP_Quarter' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\UNP\UNP_Quarter.csv.
# DataFrame 'UNP_Segments_Annual_2002' created with shape (183, 46) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\UNP\UNP_Segments_Annual_2002.csv.
# DataFrame 'UNP_Segments_Quarter_2003_ALL_To_Clean' created with shape (172, 174) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\UNP\UNP_Segments_Quarter_2003_ALL_To_Clean.csv.
# DataFrame 'UNP_Segments_Quarter_2004-2014_ALL_To_Clean' created with shape (66, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\UNP\UNP_Segments_Quarter_2004-2014_ALL_To_Clean.csv.
# DataFrame 'UNP_Segments_Quarter_2009-2018_ALL_To_Clean' created with shape (116, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\UNP\UNP_Segments_Quarter_2009-2018_ALL_To_Clean.csv.
# DataFrame 'UNP_Segments_Quarter_2014-2024_ALL_To_Clean' created with shape (173, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Miscellaneous\UNP\UNP_Segments_Quarter_2014-2024_ALL_To_Clean.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Real Estate
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Real Estate\AMT
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Real Estate\AMT
# DataFrame 'AMT_Annual_Template' created with shape (321, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Real Estate\AMT\AMT_Annual_Template.csv.
# DataFrame 'AMT_Quarter_Template' created with shape (170, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Real Estate\AMT\AMT_Quarter_Template.csv.
# DataFrame 'AMT_Segments_Quarter_2004' created with shape (21, 6) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Real Estate\AMT\AMT_Segments_Quarter_2004.csv.
# DataFrame 'AMT_Segments_Quarter_2014' created with shape (114, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Real Estate\AMT\AMT_Segments_Quarter_2014.csv.
# DataFrame 'AMT_Segments_Quarter_2024' created with shape (104, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Real Estate\AMT\AMT_Segments_Quarter_2024.csv.
# DataFrame 'AMT_Segments_Yearly_2023' created with shape (119, 42) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Real Estate\AMT\AMT_Segments_Yearly_2023.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Real Estate\EQIX
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Real Estate\EQIX
# DataFrame 'EQIX_Annual_Template' created with shape (321, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Real Estate\EQIX\EQIX_Annual_Template.csv.
# DataFrame 'EQIX_Quarter_Template' created with shape (170, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Real Estate\EQIX\EQIX_Quarter_Template.csv.
# DataFrame 'EQIX_Segments_Quarter_2014' created with shape (36, 70) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Real Estate\EQIX\EQIX_Segments_Quarter_2014.csv.
# DataFrame 'EQIX_Segments_Quarter_2024' created with shape (47, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Real Estate\EQIX\EQIX_Segments_Quarter_2024.csv.
# DataFrame 'EQIX_Segments_Yearly_2023' created with shape (51, 42) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Real Estate\EQIX\EQIX_Segments_Yearly_2023.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Real Estate\PLD
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Real Estate\PLD
# DataFrame 'PLD_Annual_Template' created with shape (321, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Real Estate\PLD\PLD_Annual_Template.csv.
# DataFrame 'PLD_Quarter' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Real Estate\PLD\PLD_Quarter.csv.
# DataFrame 'PLD_Segments_Quarter_2014' created with shape (83, 48) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Real Estate\PLD\PLD_Segments_Quarter_2014.csv.
# DataFrame 'PLD_Segments_Quarter_2024' created with shape (118, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Real Estate\PLD\PLD_Segments_Quarter_2024.csv.
# DataFrame 'PLD_Segments_Yearly_2023' created with shape (124, 32) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Real Estate\PLD\PLD_Segments_Yearly_2023.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Technology
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Technology\AAPL
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Technology\AAPL
# DataFrame 'AAPL_Annual_1990' created with shape (309, 35) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Technology\AAPL\AAPL_Annual_1990.csv.
# DataFrame 'AAPL_Quarter_1990' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Technology\AAPL\AAPL_Quarter_1990.csv.
# DataFrame 'AAPL_Segments_Quarter_2004' created with shape (47, 16) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Technology\AAPL\AAPL_Segments_Quarter_2004.csv.
# DataFrame 'AAPL_Segments_Quarter_2014' created with shape (71, 80) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Technology\AAPL\AAPL_Segments_Quarter_2014.csv.
# DataFrame 'AAPL_Segments_Quarter_2024' created with shape (46, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Technology\AAPL\AAPL_Segments_Quarter_2024.csv.
# DataFrame 'AAPL_Segments_Yearly_2023' created with shape (104, 44) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Technology\AAPL\AAPL_Segments_Yearly_2023.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Technology\MSFT
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Technology\MSFT
# DataFrame 'MSFT_Annual_1990' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Technology\MSFT\MSFT_Annual_1990.csv.
# DataFrame 'MSFT_Quarter_1990' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Technology\MSFT\MSFT_Quarter_1990.csv.
# DataFrame 'MSFT_Segments_Quarter_2014' created with shape (90, 38) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Technology\MSFT\MSFT_Segments_Quarter_2014.csv.
# DataFrame 'MSFT_Segments_Quarter_2024' created with shape (156, 42) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Technology\MSFT\MSFT_Segments_Quarter_2024.csv.
# DataFrame 'MSFT_Segments_Yearly_2024' created with shape (217, 42) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Technology\MSFT\MSFT_Segments_Yearly_2024.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Technology\NVDA
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Technology\NVDA
# DataFrame 'NVDA_Annual_1990' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Technology\NVDA\NVDA_Annual_1990.csv.
# DataFrame 'NVDA_Quarter_1990' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Technology\NVDA\NVDA_Quarter_1990.csv.
# DataFrame 'NVDA_Segments_Quarter_2015' created with shape (43, 78) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Technology\NVDA\NVDA_Segments_Quarter_2015.csv.
# DataFrame 'NVDA_Segments_Quarter_2025' created with shape (52, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Technology\NVDA\NVDA_Segments_Quarter_2025.csv.
# DataFrame 'NVDA_Segments_Yearly_2024' created with shape (63, 42) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Technology\NVDA\NVDA_Segments_Yearly_2024.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Utilities
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Utilities\DUK
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Utilities\DUK
# DataFrame 'DUK_Quarter_1990' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Utilities\DUK\DUK_Quarter_1990.csv.
# DataFrame 'DUK_Segments_Quarter_2014' created with shape (245, 78) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Utilities\DUK\DUK_Segments_Quarter_2014.csv.
# DataFrame 'DUK_Segments_Quarter_2024' created with shape (358, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Utilities\DUK\DUK_Segments_Quarter_2024.csv.
# DataFrame 'DUK_Segments_Yearly_2023' created with shape (443, 42) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Utilities\DUK\DUK_Segments_Yearly_2023.csv.
# DataFrame 'DUK_Yearly_1990' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Utilities\DUK\DUK_Yearly_1990.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Utilities\NEE
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Utilities\NEE
# DataFrame 'NEE_Quarter_1990' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Utilities\NEE\NEE_Quarter_1990.csv.
# DataFrame 'NEE_Segments_Quarter_2004' created with shape (22, 32) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Utilities\NEE\NEE_Segments_Quarter_2004.csv.
# DataFrame 'NEE_Segments_Quarter_2014' created with shape (183, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Utilities\NEE\NEE_Segments_Quarter_2014.csv.
# DataFrame 'NEE_Segments_Quarter_2024' created with shape (238, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Utilities\NEE\NEE_Segments_Quarter_2024.csv.
# DataFrame 'NEE_Segments_Yearly_2023' created with shape (284, 48) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Utilities\NEE\NEE_Segments_Yearly_2023.csv.
# DataFrame 'NEE_Yearly_1990' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Utilities\NEE\NEE_Yearly_1990.csv.
# Checking folder: C:\Users\matth\Risk-Lab-\Bloomberg\Raw_data\Utilities\SO
# Created subfolder: C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Utilities\SO
# DataFrame 'SO_Quarter_1990' created with shape (169, 141) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Utilities\SO\SO_Quarter_1990.csv.
# DataFrame 'SO_Segments_Quarter_2004' created with shape (147, 30) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Utilities\SO\SO_Segments_Quarter_2004.csv.
# DataFrame 'SO_Segments_Quarter_2014' created with shape (236, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Utilities\SO\SO_Segments_Quarter_2014.csv.
# DataFrame 'SO_Segments_Quarter_2024' created with shape (356, 82) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Utilities\SO\SO_Segments_Quarter_2024.csv.
# DataFrame 'SO_Segments_Yearly_2023' created with shape (447, 48) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Utilities\SO\SO_Segments_Yearly_2023.csv.
# DataFrame 'SO_Yearly_1990' created with shape (309, 36) and saved as CSV at C:\Users\matth\Risk-Lab-\Bloomberg\Working_Data\Utilities\SO\SO_Yearly_1990.csv.
# DataFrames created and saved as CSVs:
# PX_LAST_ALL_1990
# GOOGL_Segments_Quarter_2014
# GOOGL_Segments_Quarter_2024
# GOOGL_Segments_Yearly_2023
# GOOG_Annual
# GOOG_Quarter
# META_Annual
# META_Quarter
# META_Segments_Quarter_2014
# META_Segments_Quarter_2024
# META_Segments_Yearly_2023
# NFLX_Annual
# NFLX_Quarter
# NFLX_Segments_Quarter_2014
# NFLX_Segments_Quarter_2024
# NFLX_Segments_Yearly_2023
# BYDDY_Annual
# BYDDY_Quarter
# BYDDY_Segments_Annual_2003
# BYDDY_Segments_Quarter_2018
# TM_Annual
# TM_Quarter
# TM_Segments_Annual
# TM_Segments_Quarter_2013
# TM_Segments_Quarter_2018
# TM_Segments_Quarter_2024
# Telsa_Segments_Quarter_2024
# Tesla_Segments_ Annual
# Tesla_Segments_ Quarter_2009
# Tesla_Segments_Quarter_2023
# TSLA_Annual
# TSLA_Quarter
# Costco_Quarter_Template
# COST_Annual_Template
# COST_Segments_Quarter_2004
# COST_Segments_Quarter_2014
# COST_Segments_Quarter_2024
# COST_Segments_Yearly_2024
# PG_Annual_Template
# PG_Quarter_Template
# PG_Segments_Quarter_2005
# PG_Segments_Quarter_2015
# PG_Segments_Quarter_2025
# PG_Segments_Yearly_2024
# WMT_Annual_Template
# WMT_Quarter_Template
# WMT_Segments_Quarter_2005
# WMT_Segments_Quarter_2015
# WMT_Segments_Quarter_2025
# WMT_Segments_Yearly_2024
# CVX_Annual
# CVX_Quarter
# CVX_Segments_Annual_2000
# CVX_Segments_Quarter_2000
# CVX_Segments_Quarter_2004
# CVX_Segments_Quarter_2014
# PCCYF_Annual
# PCCYF_Quarter
# PCCYF_Segments_Annual_2005
# PCCYF_Segments_Quarter_2007
# PCCYF_Segments_Quarter_2014
# XOM_Annual
# XOM_Quarter
# XOM_Segments_Annual_2000
# XOM_Segments_Quarter_2000
# XOM_Segments_Quarter_2004
# XOM_Segments_Quarter_2014
# BRK-B_Annual
# BRK-B_Quarter
# BRK-B_Segments_Annual_2000
# BRK-B_Segments_Quarter_2001
# BRK-B_Segments_Quarter_2004
# BRK-B_Segments_Quarter_2014
# JPM_Quarter_1990 - Copy-annotated-dd
# JPM_Quarter_1990
# JPM_Segments_Quarter_2001
# JPM_Segments_Quarter_2004
# JPM_Segments_Quarter_2014
# JPM_Segments_Yearly_2001
# JPM_Yearly_1990 - Copy-DD-annotated
# JPM_Yearly_1990
# V_Quarter_1990
# V_Segments_Quarter_2008
# V_Segments_Quarter_2014
# V_Segments_Yearly_2005
# V_Yearly_1990
# JNJ_Quarter_1990
# JNJ_Segments_Quarterly_2001
# JNJ_Segments_Quarterly_2005
# JNJ_Segments_Quarterly_2015
# JNJ_Segments_Yearly_2001
# JNJ_Yearly_1990
# LLY_Quarter_1990
# LLY_Segments_Quarter_2006
# LLY_Segments_Quarter_2015
# LLY_Segments_Yearly_2004
# LLY_Yearly_1990
# UNH_Annual_1990
# UNH_Quarter_1990
# UNH_Segments_Quarter_2000
# UNH_Segments_Quarter_2004
# UNH_Segments_Quarter_2014
# UNH_Segments_Yearly_2000
# CAT_Annual_1990
# CAT_Quarter_1990
# CAT_Segments_Quarter_2004
# CAT_Segments_Quarter_2014
# CAT_Segments_Quarter_2024
# CAT_Segments_Yearly_2023
# GE_Quarterly_1990
# GE_Segments_Quarter_2004
# GE_Segments_Quarter_2014
# GE_Segments_Yearly_2004
# GE_Yearly_1990
# RTX_Quarter_1990
# RTX_Segments_Quarter_2004
# RTX_Segments_Quarter_2014
# RTX_Segments_Quarter_2024
# RTX_Segments_Yearly_2023
# RTX_Yearly_1990
# DD_Annual_Template
# DD_Quarter_Template
# DD_Segments_Quarter_2024
# DD_Segments_Yearly_2023
# MLM_Annual_Template
# MLM_Quarter_Template
# MLM_Segments_Quarter_2004
# MLM_Segments_Quarter_2014
# MLM_Segments_Quarter_2024
# MLM_Segments_Yearly_2023
# VMC_Annual_Template
# VMC_Quarter_Template
# VMC_Segments_Quarter_2004
# VMC_Segments_Quarter_2014
# VMC_Segments_Quarter_2024
# VMC_Segments_Yearly_2023
# CSX_Annual
# CSX_Quarter
# CSX_Segments_Annual_2003
# CSX_Segments_Quarter_2004
# CSX_Segments_Quarter_2009
# CSX_Segments_Quarter_2014
# NSC_Annual
# NSC_Quarter
# NSC_Segments_Annual_2003
# NSC_Segments_Quarter_2003
# NSC_Segments_Quarter_2013
# NSC_Segments_Quarter_2014
# UNP_Annual
# UNP_Quarter
# UNP_Segments_Annual_2002
# UNP_Segments_Quarter_2003_ALL_To_Clean
# UNP_Segments_Quarter_2004-2014_ALL_To_Clean
# UNP_Segments_Quarter_2009-2018_ALL_To_Clean
# UNP_Segments_Quarter_2014-2024_ALL_To_Clean
# AMT_Annual_Template
# AMT_Quarter_Template
# AMT_Segments_Quarter_2004
# AMT_Segments_Quarter_2014
# AMT_Segments_Quarter_2024
# AMT_Segments_Yearly_2023
# EQIX_Annual_Template
# EQIX_Quarter_Template
# EQIX_Segments_Quarter_2014
# EQIX_Segments_Quarter_2024
# EQIX_Segments_Yearly_2023
# PLD_Annual_Template
# PLD_Quarter
# PLD_Segments_Quarter_2014
# PLD_Segments_Quarter_2024
# PLD_Segments_Yearly_2023
# AAPL_Annual_1990
# AAPL_Quarter_1990
# AAPL_Segments_Quarter_2004
# AAPL_Segments_Quarter_2014
# AAPL_Segments_Quarter_2024
# AAPL_Segments_Yearly_2023
# MSFT_Annual_1990
# MSFT_Quarter_1990
# MSFT_Segments_Quarter_2014
# MSFT_Segments_Quarter_2024
# MSFT_Segments_Yearly_2024
# NVDA_Annual_1990
# NVDA_Quarter_1990
# NVDA_Segments_Quarter_2015
# NVDA_Segments_Quarter_2025
# NVDA_Segments_Yearly_2024
# DUK_Quarter_1990
# DUK_Segments_Quarter_2014
# DUK_Segments_Quarter_2024
# DUK_Segments_Yearly_2023
# DUK_Yearly_1990
# NEE_Quarter_1990
# NEE_Segments_Quarter_2004
# NEE_Segments_Quarter_2014
# NEE_Segments_Quarter_2024
# NEE_Segments_Yearly_2023
# NEE_Yearly_1990
# SO_Quarter_1990
# SO_Segments_Quarter_2004
# SO_Segments_Quarter_2014
# SO_Segments_Quarter_2024
# SO_Segments_Yearly_2023
# SO_Yearly_1990
